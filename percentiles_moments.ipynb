# %%
# Percentiles

import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 0.015478576616507936

# %%
np.percentile(vals, 90)
# Out:
# 0.6599039069390578

# %%
np.percentile(vals, 20)
# Out:
# -0.40871667733036005

# %%
# Moments - mean, variance, skew, kurtosis

import numpy as np
import matplotlib.pyplot as plt

vals = np.random.normal(0, 0.5, 10000)

plt.hist(vals, 50)
plt.show()

# %%
np.mean(vals)
# Out:
# -0.0015211194020160687

# %%
np.var(vals)
# Out:
# 0.25251306757601677

# %%
import scipy.stats as sp
sp.skew(vals)
# Out:
# -0.014412265846657977

# %%
sp.kurtosis(vals)
# Out:
# 0.009796227881483599
