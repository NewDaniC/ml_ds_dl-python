# %%
import numpy as np
import matplotlib.pyplot as plt

incomes = np.random.normal(100.0, 20.0, 10000)

plt.hist(incomes, 50)
plt.show()

# %%
# Standard Deviation
incomes.std()
# Out:
# 19.931997588509507

# %%
# Variation
incomes.var()
# Out:
# 397.28452786834885
